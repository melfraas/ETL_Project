# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
users = [228, 127, 113, 108, 87]
x_axis = np.arange(len(users))

# %%
# We apply align="edge" to ensure our bars line up with our tick marks
plt.bar(x_axis, users, color='r', alpha=0.80, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["California", "New York", "Texas", "Pennsylvania", "Illinois"])
# Out:
# ([<matplotlib.axis.XTick at 0x2dad400c208>,
# ...
#  [Text(-1.0, 0, 'California'),
#   Text(0.0, 0, 'New York'),
#   Text(1.0, 0, 'Texas'),
#   Text(2.0, 0, 'Pennsylvania'),
#   Text(3.0, 0, 'Illinois')])

# %%
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
plt.ylim(0, max(users)+300)
# Out:
# (0.0, 528.0)

# %%
plt.title("Schools")
plt.xlabel("States")
plt.ylabel("Number of Schools Per State")
# Out:
# Text(38.097222222222214, 0.5, 'Number of Schools Per State')
