# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
users = [228, 127, 52000, 30000, 9000]
x_axis = np.arange(len(users))

# %%
# We apply align="edge" to ensure our bars line up with our tick marks
plt.bar(x_axis, users, color='r', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["California", "New York", "Texas", "Pennsylvania", "Illinois"])
# Out:
# ([<matplotlib.axis.XTick at 0x2dad3a7ad68>,
#   <matplotlib.axis.XTick at 0x2dad3a7ae80>,
#   <matplotlib.axis.XTick at 0x2dad3d2ff60>,
#   <matplotlib.axis.XTick at 0x2dad3d3f668>,
#   <matplotlib.axis.XTick at 0x2dad3d3fe48>],
#  [Text(0, 0, 'California'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'Texas'),
#   Text(3, 0, 'Pennsylvania'),
#   Text(4, 0, 'Illinois')])
